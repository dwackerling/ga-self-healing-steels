# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\juanp\OneDrive\Escritorio\sh_ga\runs\ga_results.csv")
print(df.loc[df.ok_go_no_go==False, "gng_reason"].value_counts().head(10))
# Out:
# gng_reason
# BCC_A2 too low at t_hom             312
# LIQ>0 at t_hom                       54
# FCC_A1#2 below minimum at T_eval     52
# BCC_A2 too low at T_eval             39
# Name: count, dtype: int64

# %%
df['val_t_hom'].describe()
# Out:
# count     457.000000
# mean     1097.035011
# std       113.203041
# min       900.000000
# 25%       995.000000
# 50%      1090.000000
# 75%      1195.000000
# max      1300.000000
# Name: val_t_hom, dtype: float64

# %%
df['val_C'].describe()
# Out:
# count    457.000000
# mean       0.087757
# std        0.022122
# min        0.050000
# 25%        0.068000
# 50%        0.089000
# 75%        0.106000
# max        0.126000
# Name: val_C, dtype: float64

# %%
df[df['ok_go_no_go'] == True]
# Out:
# Empty DataFrame
# Columns: [ts, gen, phase, eval_id, code_int, code_hex, fit_df_surface, fit_neg_df_bulk, DF_bulk, IE_bulk, DF_surface, IE_surface, ok_go_no_go, T_eval_C, elapsed_s, from_cache, val_C, val_B, val_N, val_Mn, val_Si, val_Cr, val_Mo, val_V, val_Ni, val_Ti, val_Al, val_Nb, val_W, val_t_hom, val_version, val_flags, val_crc8, val_spare, bulk_C, bulk_B, bulk_N, bulk_Mn, bulk_Si, bulk_Cr, bulk_Mo, bulk_V, bulk_Ni, bulk_Ti, bulk_Al, bulk_Nb, bulk_W, gng_reason, gng_LIQ, gng_BCC_A2@t_hom, gng_BCC_A2, gng_Cr_matrix_wt, gng_FCC_A1#2, gng_M23C6_D84, gng_D_Fe, gng_D_Mo, gng_D_W, gng_D_Mo_minus_D_Fe, gng_D_W_minus_D_Fe]
# Index: []
#
# [0 rows x 59 columns]
